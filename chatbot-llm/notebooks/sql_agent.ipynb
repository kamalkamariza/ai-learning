# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from langchain_openai.chat_models import ChatOpenAI
from langchain_community.utilities import SQLDatabase
from langchain_community.agent_toolkits import create_sql_agent

# %%
load_dotenv("../.env")

LEAF_TABLE_NAME = "form_127"
LEAF_DB_NAME = "eform_data"
LEAF_DB_USER = "kamalleaf"
LEAF_DB_PASS = os.getenv("LEAF_DB_PASS")
LEAF_DB_HOST = "13.214.63.7"

LLM = ChatOpenAI(model="gpt-4-turbo")

# %%
db = SQLDatabase.from_uri(
    f"mysql+mysqlconnector://{LEAF_DB_USER}:{LEAF_DB_PASS}@{LEAF_DB_HOST}/{LEAF_DB_NAME}"
)

# %%
print(db.dialect)
print(db.get_usable_table_names())
# Out:
# mysql
# ['eform_titles', 'form_127', 'form_131', 'form_145', 'form_155', 'form_156', 'form_158', 'form_170', 'form_171', 'form_data_testing']

# %%
SQL_PREFIX = """You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.
Unless the user specifies a specific number of examples they wish to obtain, always limit your query to at most {top_k} results.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the below tools. Only use the information returned by the below tools to construct your final answer.
You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.
DO NOT create any new table to the database.

If the question does not seem related to the database, just return "I don't know" as the answer.
"""

# %%
SQL_FUNCTIONS_SUFFIX = f"""I should only look in {LEAF_TABLE_NAME} table.  Then I should query the schema"""

# %%
agent_executor = create_sql_agent(
    LLM, db=db, agent_type="openai-tools", verbose=True, prefix=SQL_PREFIX
)

# %%
agent_executor
# Out:
# AgentExecutor(name='SQL Agent Executor', verbose=True, agent=RunnableMultiActionAgent(runnable=RunnableAssign(mapper={
#   agent_scratchpad: RunnableLambda(lambda x: format_to_openai_tool_messages(x['intermediate_steps']))
# })
# | ChatPromptTemplate(input_variables=['agent_scratchpad', 'input'], input_types={'agent_scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]}, messages=[SystemMessage(content='You are an agent designed to interact with a SQL database.\nGiven an input question, create a syntactically correct mysql query to run, then look at the results of the query and return the answer.\nUnless the user specifies a specific number of examples they wish to obtain, always limit your query to at most 10 results.\nYou can order the results by a relevant column to return the most interesting examples in the database.\nNever query for all the columns from a specific table, only ask for the relevant columns given the question.\nYou have access to tools for interacting with the database.\nOnly use the below tools. Only use the information returned by the below tools to construct your final answer.\nYou MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.\n\nDO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.\nDO NOT create any new table to the database.\n\nIf the question does not seem related to the database, just return "I don\'t know" as the answer.\n'), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')), AIMessage(content='I should look at the tables in the database to see what I can query.  Then I should query the schema of the most relevant tables.'), MessagesPlaceholder(variable_name='agent_scratchpad')])
# | RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x000001CF7FA129C0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x000001CF7F8FAB10>, model_name='gpt-4-turbo', openai_api_key=SecretStr('**********'), openai_proxy=''), kwargs={'tools': [{'type': 'function', 'function': {'name': 'sql_db_query', 'description': "Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.", 'parameters': {'type': 'object', 'properties': {'query': {'description': 'A detailed and correct SQL query.', 'type': 'string'}}, 'required': ['query']}}}, {'type': 'function', 'function': {'name': 'sql_db_schema', 'description': 'Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3', 'parameters': {'type': 'object', 'properties': {'table_names': {'description': "A comma-separated list of the table names for which to return the schema. Example input: 'table1, table2, table3'", 'type': 'string'}}, 'required': ['table_names']}}}, {'type': 'function', 'function': {'name': 'sql_db_list_tables', 'description': 'Input is an empty string, output is a comma-separated list of tables in the database.', 'parameters': {'type': 'object', 'properties': {'tool_input': {'description': 'An empty string', 'default': '', 'type': 'string'}}}}}, {'type': 'function', 'function': {'name': 'sql_db_query_checker', 'description': 'Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!', 'parameters': {'type': 'object', 'properties': {'query': {'description': 'A detailed and SQL query to be checked.', 'type': 'string'}}, 'required': ['query']}}}]})
# | OpenAIToolsAgentOutputParser(), input_keys_arg=['input'], return_keys_arg=['output'], stream_runnable=True), tools=[QuerySQLDataBaseTool(description="Input to this tool is a detailed and correct SQL query, output is a result from the database. If the query is not correct, an error message will be returned. If an error is returned, rewrite the query, check the query, and try again. If you encounter an issue with Unknown column 'xxxx' in 'field list', use sql_db_schema to query the correct table fields.", db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001CF7FA0F1A0>), InfoSQLDatabaseTool(description='Input to this tool is a comma-separated list of tables, output is the schema and sample rows for those tables. Be sure that the tables actually exist by calling sql_db_list_tables first! Example Input: table1, table2, table3', db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001CF7FA0F1A0>), ListSQLDatabaseTool(db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001CF7FA0F1A0>), QuerySQLCheckerTool(description='Use this tool to double check if your query is correct before executing it. Always use this tool before executing a query with sql_db_query!', db=<langchain_community.utilities.sql_database.SQLDatabase object at 0x000001CF7FA0F1A0>, llm=ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x000001CF7FA129C0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x000001CF7F8FAB10>, model_name='gpt-4-turbo', openai_api_key=SecretStr('**********'), openai_proxy=''), llm_chain=LLMChain(prompt=PromptTemplate(input_variables=['dialect', 'query'], template='\n{query}\nDouble check the {dialect} query above for common mistakes, including:\n- Using NOT IN with NULL values\n- Using UNION when UNION ALL should have been used\n- Using BETWEEN for exclusive ranges\n- Data type mismatch in predicates\n- Properly quoting identifiers\n- Using the correct number of arguments for functions\n- Casting to the correct data type\n- Using the proper columns for joins\n\nIf there are any of the above mistakes, rewrite the query. If there are no mistakes, just reproduce the original query.\n\nOutput the final SQL query only.\n\nSQL Query: '), llm=ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x000001CF7FA129C0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x000001CF7F8FAB10>, model_name='gpt-4-turbo', openai_api_key=SecretStr('**********'), openai_proxy='')))])

# %%
agent_executor.invoke({"input": "how many meetings are there?"})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# eform_titles, form_127, form_131, form_145, form_155, form_156, form_158, form_170, form_171, form_data_testing
# Invoking: `sql_db_schema` with `{'table_names': 'form_127, form_131, form_145, form_155, form_156, form_158, form_170, form_171'}`
#
#
#
# CREATE TABLE form_127 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_127 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	entry_date	last_submit_date
# 1	127	149	29741	114	2024-06-25 10:19:04	2024-06-25 10:19:04
# 2	127	150	29741	114	2024-06-26 01:57:06	2024-06-26 01:57:06
# 3	127	151	29741	114	2024-06-26 02:02:01	2024-06-26 02:02:01
# */
#
#
# CREATE TABLE form_131 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	`ta_PropertyNameAndDetails` TEXT,
# 	`tf_MeetingMinuteSubject` TEXT,
# 	`dt_DateandTimeOfMeetingMinute` TEXT,
# 	`tf_JointManagementCommitteeMember` TEXT,
# 	`tf_InitialName` TEXT,
# 	`tf_CommitteeUnitNo` TEXT,
# 	`sel_MemberDesignation` TEXT,
# 	`tf_MeetingAttendance` TEXT,
# 	`tf_JointManagementCommitteeMember1` TEXT,
# 	`tf_InitialName1` TEXT,
# 	`tf_CommitteeUnitNo1` TEXT,
# 	`sel_MemberDesignation1` TEXT,
# 	`tf_MeetingAttendance1` TEXT,
# 	`tf_JointManagementCommitteeMember2` TEXT,
# 	`tf_InitialName2` TEXT,
# 	`tf_CommitteeUnitNo2` TEXT,
# 	`sel_MemberDesignation2` TEXT,
# 	`tf_MeetingAttendance2` TEXT,
# 	`tf_JointManagementCommitteeMember3` TEXT,
# 	`tf_InitialName3` TEXT,
# 	`tf_CommitteeUnitNo3` TEXT,
# 	`sel_MemberDesignation3` TEXT,
# 	`tf_MeetingAttendance3` TEXT,
# 	`tf_JointManagementCommitteeMember4` TEXT,
# 	`tf_InitialName4` TEXT,
# 	`tf_CommitteeUnitNo4` TEXT,
# 	`sel_MemberDesignation4` TEXT,
# 	`tf_MeetingAttendance4` TEXT,
# 	`tf_JointManagementCommitteeMember5` TEXT,
# 	`tf_InitialName5` TEXT,
# 	`tf_CommitteeUnitNo5` TEXT,
# 	`sel_MemberDesignation5` TEXT,
# 	`tf_MeetingAttendance5` TEXT,
# 	`Adduserrow2` TEXT,
# 	`Remove3` TEXT,
# 	`NumberOfRows` TEXT,
# 	`tf_PropertyManagementMember` TEXT,
# 	`tf_PropertyManagementMemberInitial` TEXT,
# 	`sel_PropertyManagementMemberDesignation` TEXT,
# 	`tf_PropertyManagementMemberAttendance` TEXT,
# 	`tf_PropertyManagementMember1` TEXT,
# 	`tf_PropertyManagementMemberInitial1` TEXT,
# 	`sel_PropertyManagementMemberDesignation1` TEXT,
# 	`tf_PropertyManagementMemberAttendance1` TEXT,
# 	`tf_PropertyManagementMember2` TEXT,
# 	`tf_PropertyManagementMemberInitial2` TEXT,
# 	`sel_PropertyManagementMemberDesignation2` TEXT,
# 	`tf_PropertyManagementMemberAttendance2` TEXT,
# 	`tf_PropertyManagementMember3` TEXT,
# 	`tf_PropertyManagementMemberInitial3` TEXT,
# 	`sel_PropertyManagementMemberDesignation3` TEXT,
# 	`tf_PropertyManagementMemberAttendance3` TEXT,
# 	`tf_PropertyManagementMember4` TEXT,
# 	`textField41` TEXT,
# 	`sel_PropertyManagementMemberDesignation4` TEXT,
# 	`tf_PropertyManagementMemberAttendance4` TEXT,
# 	`NumberOfPM` TEXT,
# 	`Adduserrow1` TEXT,
# 	`Remove2` TEXT,
# 	`ta_MeetingAnnouncement` TEXT,
# 	`ta_ActionBy` TEXT,
# 	`textArea2` TEXT,
# 	`ta_MeetingAnnouncement1` TEXT,
# 	`ta_ActionBy1` TEXT,
# 	`ta_ActionToBeTaken2` TEXT,
# 	`ta_MeetingAnnouncement3` TEXT,
# 	`ta_ActionBy3` TEXT,
# 	`ta_ActionToBeTaken3` TEXT,
# 	`ta_MeetingAnnouncement4` TEXT,
# 	`ta_ActionBy4` TEXT,
# 	`ta_ActionToBeTaken4` TEXT,
# 	`ta_MeetingAnnouncement5` TEXT,
# 	`ta_ActionBy5` TEXT,
# 	`ta_ActionToBeTaken5` TEXT,
# 	`ta_MeetingAnnouncement6` TEXT,
# 	`ta_ActionBy6` TEXT,
# 	`ta_ActionToBeTaken6` TEXT,
# 	`ta_MeetingAnnouncement7` TEXT,
# 	`ta_ActionBy7` TEXT,
# 	`ta_ActionToBeTaken7` TEXT,
# 	`NumberofAgenda` TEXT,
# 	`Adduserrow3` TEXT,
# 	`Remove4` TEXT,
# 	submit TEXT,
# 	`FormTitle` TEXT,
# 	`FormDescription` TEXT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_131 table:
# id	ta_PropertyNameAndDetails	tf_MeetingMinuteSubject	dt_DateandTimeOfMeetingMinute	tf_JointManagementCommitteeMember	tf_InitialName	tf_CommitteeUnitNo	sel_MemberDesignation	tf_MeetingAttendance	tf_JointManagementCommitteeMember1	tf_InitialName1	tf_CommitteeUnitNo1	sel_MemberDesignation1	tf_MeetingAttendance1	tf_JointManagementCommitteeMember2	tf_InitialName2	tf_CommitteeUnitNo2	sel_MemberDesignation2	tf_MeetingAttendance2	tf_JointManagementCommitteeMember3	tf_InitialName3	tf_CommitteeUnitNo3	sel_MemberDesignation3	tf_MeetingAttendance3	tf_JointManagementCommitteeMember4	tf_InitialName4	tf_CommitteeUnitNo4	sel_MemberDesignation4	tf_MeetingAttendance4	tf_JointManagementCommitteeMember5	tf_InitialName5	tf_CommitteeUnitNo5	sel_MemberDesignation5	tf_MeetingAttendance5	Adduserrow2	Remove3	NumberOfRows	tf_PropertyManagementMember	tf_PropertyManagementMemberInitial	sel_PropertyManagementMemberDesignation	tf_PropertyManagementMemberAttendance	tf_PropertyManagementMember1	tf_PropertyManagementMemberInitial1	sel_PropertyManagementMemberDesignation1	tf_PropertyManagementMemberAttendance1	tf_PropertyManagementMember2	tf_PropertyManagementMemberInitial2	sel_PropertyManagementMemberDesignation2	tf_PropertyManagementMemberAttendance2	tf_PropertyManagementMember3	tf_PropertyManagementMemberInitial3	sel_PropertyManagementMemberDesignation3	tf_PropertyManagementMemberAttendance3	tf_PropertyManagementMember4	textField41	sel_PropertyManagementMemberDesignation4	tf_PropertyManagementMemberAttendance4	NumberOfPM	Adduserrow1	Remove2	ta_MeetingAnnouncement	ta_ActionBy	textArea2	ta_MeetingAnnouncement1	ta_ActionBy1	ta_ActionToBeTaken2	ta_MeetingAnnouncement3	ta_ActionBy3	ta_ActionToBeTaken3	ta_MeetingAnnouncement4	ta_ActionBy4	ta_ActionToBeTaken4	ta_MeetingAnnouncement5	ta_ActionBy5	ta_ActionToBeTaken5	ta_MeetingAnnouncement6	ta_ActionBy6	ta_ActionToBeTaken6	ta_MeetingAnnouncement7	ta_ActionBy7	ta_ActionToBeTaken7	NumberofAgenda	Adduserrow3	Remove4	submit	FormTitle	FormDescription	id_digital_form_io	id_group
# 1	THE TWO CONDO
# Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal Te	LEAF Meeting	2024-05-24T12:00:00+08:00	john	mr	T-04-04	chairman	1/1	Moi	mr	T-05-05	treasurer	1/1	Lisa	ms	T-06-06	secretary	1/1	Lin	mr	T-08-08	treasurer	1/1	Erno	ms	T-11-11	treasurer	1/1	Moon	mr	T-12-12	committee	1/1			0	woos				xander				wukong												0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend	Info		Project Updates:
#
# Project Alpha: Lin reported that the project is on schedule, with the next milesto	Info		Adjournment:
#
# The meeting was adjourned at 11:30 AM.	Info		Asset Management:
#
# Maintenance Activity: swimming pool maintenance needed for June 15, 2024, at 10:0	Info		Next Meeting Date:
#
# The next meeting is scheduled for June 17, 2024, at 10:00 AM in Conference Room 	Info								0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# 2	The Leaf Condominium	MC Meeting No.10	2024-05-17T12:00:00+08:00	Lee Sian Lee	LSL	T-04-04	chairman	1/1	Tan Kim Seng	TKS	T-05-05	secretary	1/1	Wong Wei Kang	WWK	T-06-06	treasurer	1/1	Teow Wei Yoong	TWY	T-08-08	committee	1/1	Lai Choon Fai	LCF	T-11-11	developerRepresentative	1/1	Chong Ken Yung	CKY	T-12-12	developerRepresentative	1/1			0	Chia Wei Ping	CWP	seniorPropertyManager	1/1	Chan Rong Bang	CRB	buildingManager	1/1	Yap Sin Yee	YSY	accountManager	1/1	Thomas Yeap	TY	buildingExecutive	1/1	Jacky Ling	JL	accountExecutive	1/1	0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend	Info		Project Updates:
#
# Project Alpha: CRB reported that the project is on schedule, with the next milesto	Info		Adjournment:
#
# The meeting was adjourned at 11:30 AM.	Info		New Business:
#
# Team Building Activity: CRB suggested organizing a team-building retreat. JL will loo	JL to propose date and venue		Seeking for  Approval to replace faulty swimming pool water pump
#
# CRB reported that the swimming po	PO to be issued by TY		Next Meeting Date:
#
# The next meeting is scheduled for August 17, 2024, at 10:00 AM in Conference Roo	Info					0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# 3	THE TREE CONDO
# Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal T	LEAF Meeting	2024-05-25T12:00:00+08:00	johnny	mr	101	secretary	1/1	joe	mr	102	treasurer	1/1	rang	mrs	103	chairman	1/1																		0																					0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend																					0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# */
#
#
# CREATE TABLE form_145 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`NatureOfIncidentReport` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened` DATETIME,
# 	`LocationOfTheIncidentHappened` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened1` DATETIME,
# 	`LocationOfTheIncidentHappened1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened2` DATETIME,
# 	`LocationOfTheIncidentHappened2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened3` DATETIME,
# 	`LocationOfTheIncidentHappened3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened4` DATETIME,
# 	`LocationOfTheIncidentHappened4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened5` DATETIME,
# 	`LocationOfTheIncidentHappened5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened6` DATETIME,
# 	`LocationOfTheIncidentHappened6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened7` DATETIME,
# 	`LocationOfTheIncidentHappened7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened8` DATETIME,
# 	`LocationOfTheIncidentHappened8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened9` DATETIME,
# 	`LocationOfTheIncidentHappened9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened10` DATETIME,
# 	`LocationOfTheIncidentHappened10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`formTitle` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`formDescription` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_145 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	NatureOfIncidentReport	DateOfIncidentHappened	LocationOfTheIncidentHappened	ActionTakanDueToTheIncident	NatureOfIncidentReport1	DateOfIncidentHappened1	LocationOfTheIncidentHappened1	ActionTakanDueToTheIncident1	NatureOfIncidentReport2	DateOfIncidentHappened2	LocationOfTheIncidentHappened2	ActionTakanDueToTheIncident2	NatureOfIncidentReport3	DateOfIncidentHappened3	LocationOfTheIncidentHappened3	ActionTakanDueToTheIncident3	NatureOfIncidentReport4	DateOfIncidentHappened4	LocationOfTheIncidentHappened4	ActionTakanDueToTheIncident4	NatureOfIncidentReport5	DateOfIncidentHappened5	LocationOfTheIncidentHappened5	ActionTakanDueToTheIncident5	NatureOfIncidentReport6	DateOfIncidentHappened6	LocationOfTheIncidentHappened6	ActionTakanDueToTheIncident6	NatureOfIncidentReport7	DateOfIncidentHappened7	LocationOfTheIncidentHappened7	ActionTakanDueToTheIncident7	NatureOfIncidentReport8	DateOfIncidentHappened8	LocationOfTheIncidentHappened8	ActionTakanDueToTheIncident8	NatureOfIncidentReport9	DateOfIncidentHappened9	LocationOfTheIncidentHappened9	ActionTakanDueToTheIncident9	NatureOfIncidentReport10	DateOfIncidentHappened10	LocationOfTheIncidentHappened10	ActionTakanDueToTheIncident10	formTitle	formDescription	entry_date	last_submit_date
#
# */
#
#
# CREATE TABLE form_155 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL DEFAULT '155',
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	entry_date DATETIME,
# 	status VARCHAR(16) NOT NULL,
# 	by_id_user INTEGER NOT NULL DEFAULT '2',
# 	completed_by_id_user INTEGER NOT NULL DEFAULT '2',
# 	inprogress_by_id_user INTEGER NOT NULL DEFAULT '2',
# 	completed_date DATETIME,
# 	inprogress_date DATETIME,
# 	`PumpOperationCondition` VARCHAR(24),
# 	`FiltrationMediaCondition` VARCHAR(24),
# 	`ElectricalControlPanelOperationCondition` VARCHAR(24),
# 	`ValvesForLeakages` VARCHAR(24),
# 	`RoomCleanliness` VARCHAR(24),
# 	`LooseTerminationOfElectricalCable` VARCHAR(24),
# 	`tf_RemarkFiltrationPumpRoom` VARCHAR(100),
# 	`In-ComingWaterSupplyCondition` VARCHAR(24),
# 	`Ball-ValveOperationCondition` VARCHAR(24),
# 	`Pump-SetOperationCondition` VARCHAR(24),
# 	`tf_RemarkBalancingTank` VARCHAR(100),
# 	`ConditionOfWater` VARCHAR(24),
# 	`WaterOverflowSystemInOrder` VARCHAR(24),
# 	`PresenceAlgaeFormationOnWall` VARCHAR(24),
# 	`CheckTestWaterpH` VARCHAR(24),
# 	`tf_RemarkWadingPool` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_155 table:
# id	id_digital_form_io	id_group	entry_date	status	by_id_user	completed_by_id_user	inprogress_by_id_user	completed_date	inprogress_date	PumpOperationCondition	FiltrationMediaCondition	ElectricalControlPanelOperationCondition	ValvesForLeakages	RoomCleanliness	LooseTerminationOfElectricalCable	tf_RemarkFiltrationPumpRoom	In-ComingWaterSupplyCondition	Ball-ValveOperationCondition	Pump-SetOperationCondition	tf_RemarkBalancingTank	ConditionOfWater	WaterOverflowSystemInOrder	PresenceAlgaeFormationOnWall	CheckTestWaterpH	tf_RemarkWadingPool	submit
# 1	155	361	2024-05-22 16:51:16	completed	29741	2	2	2024-05-25 00:00:00	2024-05-23 00:00:00	ok	ok	ok	not good	not good	ok	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# 2	155	361	2024-05-23 00:00:00	completed	29741	2	2	2024-05-26 00:00:00	2024-05-24 00:00:00	ok	ok	ok	not good	not good	ok	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# 3	155	364	2024-05-24 00:00:00	pending	2	0	0	None	None	not good	ok	ok	not good	not good	not good	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# */
#
#
# CREATE TABLE form_156 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL DEFAULT '156',
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	by_id_user INTEGER NOT NULL,
# 	entry_date DATETIME,
# 	`LcdDisplayWestEntrance` VARCHAR(24),
# 	`tf_RemarkLCDDisplayWestEntrance` VARCHAR(100),
# 	`MediaPlayerWestEntrance` VARCHAR(24),
# 	`tf_RemarkMediaPlayerWestEntrance` VARCHAR(100),
# 	`FrontLeftWestEntrance` VARCHAR(24),
# 	`SideWestEntrance` VARCHAR(24),
# 	`RearRightWestEntrance` VARCHAR(24),
# 	`tf_RemarkProjectScreenWestEntrance` VARCHAR(100),
# 	`LeftWestEntrance` VARCHAR(24),
# 	`RightWestEntrance1` VARCHAR(24),
# 	`tf_RemarkVGAPanelWestEntrance` VARCHAR(100),
# 	`LeftWestEntrance1` VARCHAR(24),
# 	`RightWestEntrance` VARCHAR(24),
# 	`tf_RemarkMIGPanelWestEntrance` VARCHAR(100),
# 	`AudioSystemWestEntrance` VARCHAR(24),
# 	`tf_RemarkAudioSystemWestEntrance` VARCHAR(100),
# 	`FOHSpeakerWestEntrance` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerWestEntrance` VARCHAR(100),
# 	`CeilingSpeakerWestEntrance` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerWestEntrance` VARCHAR(100),
# 	`ProtableSystemWestEntrance` VARCHAR(24),
# 	`tf_RemarkPortableSystemWestEntrance` VARCHAR(100),
# 	`StageLightingWestEntrance` VARCHAR(24),
# 	`tf_RemarkStageLightingWestEntrance` VARCHAR(100),
# 	`PowerOutletWestEntrance` VARCHAR(24),
# 	`tf_RemarkPowerOutletWestEntrance` VARCHAR(100),
# 	`LcdDisplayBoardRoom` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBoardRoom` VARCHAR(100),
# 	`MediaPlayerBoardRoom` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBoardRoom` VARCHAR(100),
# 	`FrontLeftBoardRoom` VARCHAR(24),
# 	`SideBoardRoom` VARCHAR(24),
# 	`RearRighBoardRoom` VARCHAR(24),
# 	`tf_RemarkProjectScreenBoardRoom` VARCHAR(100),
# 	`LeftBoardRoom1` VARCHAR(24),
# 	`RightBoardRoom` VARCHAR(24),
# 	`tf_RemarkVGAPanelBoardRoom` VARCHAR(100),
# 	`LeftBoardRoom` VARCHAR(24),
# 	`RightBoardRoom1` VARCHAR(24),
# 	`tf_RemarkMIGPanelBoardRoom` VARCHAR(100),
# 	`AudioSystemBoardRoom` VARCHAR(24),
# 	`tf_RemarkAudioSystemBoardRoom` VARCHAR(100),
# 	`FOHSpeakerBoardRoom` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBoardRoom` VARCHAR(100),
# 	`CeilingSpeakerBoardRoom` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBoardRoom` VARCHAR(100),
# 	`ProtableSystemBoardRoom` VARCHAR(24),
# 	`tf_RemarkPortableSystemBoardRoom` VARCHAR(100),
# 	`StageLightingBoardRoom` VARCHAR(24),
# 	`tf_RemarkStageLightingBoardRoom` VARCHAR(100),
# 	`PowerOutletBoardRoom` VARCHAR(24),
# 	`tf_RemarkPowerOutletBoardRoom` VARCHAR(100),
# 	`LcdDisplayBallRoom1` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom1` VARCHAR(100),
# 	`MediaPlayerBallRoom1` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom1` VARCHAR(100),
# 	`FrontLeftBallRoom1` VARCHAR(24),
# 	`SideBallRoom1` VARCHAR(24),
# 	`RearRightBallRoom1` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom1` VARCHAR(100),
# 	`LeftBallRoom1` VARCHAR(24),
# 	`RightBallRoom1` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom1` VARCHAR(100),
# 	`Left1BallRoom1` VARCHAR(24),
# 	`Right1BallRoom1` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom1` VARCHAR(100),
# 	`AudioSystemBallRoom1` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom1` VARCHAR(100),
# 	`FOHSpeakerBallRoom1` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom1` VARCHAR(100),
# 	`CeilingSpeakerBallRoom1` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom1` VARCHAR(100),
# 	`ProtableSystemBallRoom1` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom1` VARCHAR(100),
# 	`StageLightingBallRoom1` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom1` VARCHAR(100),
# 	`PowerOutletBallRoom1` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom1` VARCHAR(100),
# 	`LcdDisplayBallRoom2` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom2` VARCHAR(100),
# 	`MediaPlayerBallRoom2` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom2` VARCHAR(100),
# 	`FrontLeftBallRoom2` VARCHAR(24),
# 	`SideBallRoom2` VARCHAR(24),
# 	`RearRightBallRoom2` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom2` VARCHAR(100),
# 	`LeftBallRoom2` VARCHAR(24),
# 	`RightBallRoom2` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom2` VARCHAR(100),
# 	`Left1BallRoom2` VARCHAR(24),
# 	`Right1BallRoom2` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom2` VARCHAR(100),
# 	`AudioSystemBallRoom2` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom2` VARCHAR(100),
# 	`FOHSpeakerBallRoom2` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom2` VARCHAR(100),
# 	`CeilingSpeakerBallRoom2` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom2` VARCHAR(100),
# 	`ProtableSystemBallRoom2` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom2` VARCHAR(100),
# 	`StageLightingBallRoom2` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom2` VARCHAR(100),
# 	`PowerOutletBallRoom2` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom2` VARCHAR(100),
# 	`LcdDisplayBallRoom3` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom3` VARCHAR(100),
# 	`MediaPlayerBallRoom3` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom3` VARCHAR(100),
# 	`FrontLeftBallRoom3` VARCHAR(24),
# 	`SideBallRoom3` VARCHAR(24),
# 	`RearRightBallRoom3` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom3` VARCHAR(100),
# 	`LeftBallRoom3` VARCHAR(24),
# 	`RightBallRoom3` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom3` VARCHAR(100),
# 	`Left1BallRoom3` VARCHAR(24),
# 	`Right1BallRoom3` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom3` VARCHAR(100),
# 	`AudioSystemBallRoom3` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom3` VARCHAR(100),
# 	`FOHSpeakerBallRoom3` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom3` VARCHAR(100),
# 	`CeilingSpeakerBallRoom3` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom3` VARCHAR(100),
# 	`ProtableSystemBallRoom3` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom3` VARCHAR(100),
# 	`StageLightingBallRoom3` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom3` VARCHAR(100),
# 	`PowerOutletBallRoom3` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom3` VARCHAR(100),
# 	`LcdDisplayEastEntrance` VARCHAR(24),
# 	`tf_RemarkLCDDisplayEastEntrance` VARCHAR(100),
# 	`MediaPlayerEastEntrance` VARCHAR(24),
# 	`tf_RemarkMediaPlayerEastEntrance` VARCHAR(100),
# 	`FrontLeftEastEntrance` VARCHAR(24),
# 	`SideBallEastEntrance` VARCHAR(24),
# 	`RearRightEastEntrance` VARCHAR(24),
# 	`tf_RemarkProjectScreenEastEntrance` VARCHAR(100),
# 	`LeftEastEntrance` VARCHAR(24),
# 	`RightEastEntrance` VARCHAR(24),
# 	`tf_RemarkVGAPanelEastEntrance` VARCHAR(100),
# 	`Left1EastEntrance` VARCHAR(24),
# 	`Right1EastEntrance` VARCHAR(24),
# 	`tf_RemarkMIGPanelEastEntrance` VARCHAR(100),
# 	`AudioSystemEastEntrance` VARCHAR(24),
# 	`tf_RemarkAudioSystemEastEntrance` VARCHAR(100),
# 	`FOHSpeakerEastEntrance` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerEastEntrance` VARCHAR(100),
# 	`CeilingSpeakerEastEntrance` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerEastEntrance` VARCHAR(100),
# 	`ProtableSystemEastEntrance` VARCHAR(24),
# 	`tf_RemarkPortableSystemEastEntrance` VARCHAR(100),
# 	`StageLightingEastEntrance` VARCHAR(24),
# 	`tf_RemarkStageLightingEastEntrance` VARCHAR(100),
# 	`PowerOutletEastEntrance` VARCHAR(24),
# 	`tf_RemarkPowerOutletEastEntrance` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_156 table:
# id	id_digital_form_io	id_group	by_id_user	entry_date	LcdDisplayWestEntrance	tf_RemarkLCDDisplayWestEntrance	MediaPlayerWestEntrance	tf_RemarkMediaPlayerWestEntrance	FrontLeftWestEntrance	SideWestEntrance	RearRightWestEntrance	tf_RemarkProjectScreenWestEntrance	LeftWestEntrance	RightWestEntrance1	tf_RemarkVGAPanelWestEntrance	LeftWestEntrance1	RightWestEntrance	tf_RemarkMIGPanelWestEntrance	AudioSystemWestEntrance	tf_RemarkAudioSystemWestEntrance	FOHSpeakerWestEntrance	tf_RemarkFOHSpeakerWestEntrance	CeilingSpeakerWestEntrance	tf_RemarkCeilingSpeakerWestEntrance	ProtableSystemWestEntrance	tf_RemarkPortableSystemWestEntrance	StageLightingWestEntrance	tf_RemarkStageLightingWestEntrance	PowerOutletWestEntrance	tf_RemarkPowerOutletWestEntrance	LcdDisplayBoardRoom	tf_RemarkLCDDisplayBoardRoom	MediaPlayerBoardRoom	tf_RemarkMediaPlayerBoardRoom	FrontLeftBoardRoom	SideBoardRoom	RearRighBoardRoom	tf_RemarkProjectScreenBoardRoom	LeftBoardRoom1	RightBoardRoom	tf_RemarkVGAPanelBoardRoom	LeftBoardRoom	RightBoardRoom1	tf_RemarkMIGPanelBoardRoom	AudioSystemBoardRoom	tf_RemarkAudioSystemBoardRoom	FOHSpeakerBoardRoom	tf_RemarkFOHSpeakerBoardRoom	CeilingSpeakerBoardRoom	tf_RemarkCeilingSpeakerBoardRoom	ProtableSystemBoardRoom	tf_RemarkPortableSystemBoardRoom	StageLightingBoardRoom	tf_RemarkStageLightingBoardRoom	PowerOutletBoardRoom	tf_RemarkPowerOutletBoardRoom	LcdDisplayBallRoom1	tf_RemarkLCDDisplayBallRoom1	MediaPlayerBallRoom1	tf_RemarkMediaPlayerBallRoom1	FrontLeftBallRoom1	SideBallRoom1	RearRightBallRoom1	tf_RemarkProjectScreenBallRoom1	LeftBallRoom1	RightBallRoom1	tf_RemarkVGAPanelBallRoom1	Left1BallRoom1	Right1BallRoom1	tf_RemarkMIGPanelBallRoom1	AudioSystemBallRoom1	tf_RemarkAudioSystemBallRoom1	FOHSpeakerBallRoom1	tf_RemarkFOHSpeakerBallRoom1	CeilingSpeakerBallRoom1	tf_RemarkCeilingSpeakerBallRoom1	ProtableSystemBallRoom1	tf_RemarkPortableSystemBallRoom1	StageLightingBallRoom1	tf_RemarkStageLightingBallRoom1	PowerOutletBallRoom1	tf_RemarkPowerOutletBallRoom1	LcdDisplayBallRoom2	tf_RemarkLCDDisplayBallRoom2	MediaPlayerBallRoom2	tf_RemarkMediaPlayerBallRoom2	FrontLeftBallRoom2	SideBallRoom2	RearRightBallRoom2	tf_RemarkProjectScreenBallRoom2	LeftBallRoom2	RightBallRoom2	tf_RemarkVGAPanelBallRoom2	Left1BallRoom2	Right1BallRoom2	tf_RemarkMIGPanelBallRoom2	AudioSystemBallRoom2	tf_RemarkAudioSystemBallRoom2	FOHSpeakerBallRoom2	tf_RemarkFOHSpeakerBallRoom2	CeilingSpeakerBallRoom2	tf_RemarkCeilingSpeakerBallRoom2	ProtableSystemBallRoom2	tf_RemarkPortableSystemBallRoom2	StageLightingBallRoom2	tf_RemarkStageLightingBallRoom2	PowerOutletBallRoom2	tf_RemarkPowerOutletBallRoom2	LcdDisplayBallRoom3	tf_RemarkLCDDisplayBallRoom3	MediaPlayerBallRoom3	tf_RemarkMediaPlayerBallRoom3	FrontLeftBallRoom3	SideBallRoom3	RearRightBallRoom3	tf_RemarkProjectScreenBallRoom3	LeftBallRoom3	RightBallRoom3	tf_RemarkVGAPanelBallRoom3	Left1BallRoom3	Right1BallRoom3	tf_RemarkMIGPanelBallRoom3	AudioSystemBallRoom3	tf_RemarkAudioSystemBallRoom3	FOHSpeakerBallRoom3	tf_RemarkFOHSpeakerBallRoom3	CeilingSpeakerBallRoom3	tf_RemarkCeilingSpeakerBallRoom3	ProtableSystemBallRoom3	tf_RemarkPortableSystemBallRoom3	StageLightingBallRoom3	tf_RemarkStageLightingBallRoom3	PowerOutletBallRoom3	tf_RemarkPowerOutletBallRoom3	LcdDisplayEastEntrance	tf_RemarkLCDDisplayEastEntrance	MediaPlayerEastEntrance	tf_RemarkMediaPlayerEastEntrance	FrontLeftEastEntrance	SideBallEastEntrance	RearRightEastEntrance	tf_RemarkProjectScreenEastEntrance	LeftEastEntrance	RightEastEntrance	tf_RemarkVGAPanelEastEntrance	Left1EastEntrance	Right1EastEntrance	tf_RemarkMIGPanelEastEntrance	AudioSystemEastEntrance	tf_RemarkAudioSystemEastEntrance	FOHSpeakerEastEntrance	tf_RemarkFOHSpeakerEastEntrance	CeilingSpeakerEastEntrance	tf_RemarkCeilingSpeakerEastEntrance	ProtableSystemEastEntrance	tf_RemarkPortableSystemEastEntrance	StageLightingEastEntrance	tf_RemarkStageLightingEastEntrance	PowerOutletEastEntrance	tf_RemarkPowerOutletEastEntrance	submit
# 1	156	361	29741	2024-05-05 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		1
# 2	156	361	29741	2024-05-12 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok											None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# 3	156	361	29741	2024-05-19 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok										None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE form_158 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL COMMENT 'FK to eform_titles.id_digital_form_io' DEFAULT '158',
# 	id_group INTEGER NOT NULL COMMENT 'FK to groups' DEFAULT '361',
# 	entry_date DATETIME COMMENT 'Date of submission',
# 	`DBBoardSwitches` VARCHAR(24),
# 	`Treadmill1` VARCHAR(24),
# 	`Treadmill3` VARCHAR(24),
# 	`CrossTrainer1` VARCHAR(24),
# 	`UprightBike` VARCHAR(24),
# 	`ERower` VARCHAR(24),
# 	`LegExtension` VARCHAR(24),
# 	`LatPullDown` VARCHAR(24),
# 	`AdjustableBench` VARCHAR(24),
# 	`2TierRack` VARCHAR(24),
# 	`Upholstery` VARCHAR(24),
# 	`SwingDoor` VARCHAR(24),
# 	`Mirror` VARCHAR(24),
# 	`WallSwitchSocket` VARCHAR(24),
# 	`WallFan` VARCHAR(24),
# 	`TimberFlooring` VARCHAR(24),
# 	`Treadmill2` VARCHAR(24),
# 	`Treadmill4` VARCHAR(24),
# 	`CrossTrainer12` VARCHAR(24),
# 	`RecumbentBike` VARCHAR(24),
# 	`MultiPress` VARCHAR(24),
# 	`Abdominal` VARCHAR(24),
# 	`AbdominalBench` VARCHAR(24),
# 	`AdjustableBench2` VARCHAR(24),
# 	`PullPins` VARCHAR(24),
# 	cables VARCHAR(24),
# 	`Emergency` VARCHAR(24),
# 	`CeilingLights` VARCHAR(24),
# 	`Aircond` VARCHAR(24),
# 	`tf_RemarkRecumbentBike` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_158 table:
# id	id_digital_form_io	id_group	entry_date	DBBoardSwitches	Treadmill1	Treadmill3	CrossTrainer1	UprightBike	ERower	LegExtension	LatPullDown	AdjustableBench	2TierRack	Upholstery	SwingDoor	Mirror	WallSwitchSocket	WallFan	TimberFlooring	Treadmill2	Treadmill4	CrossTrainer12	RecumbentBike	MultiPress	Abdominal	AbdominalBench	AdjustableBench2	PullPins	cables	Emergency	CeilingLights	Aircond	tf_RemarkRecumbentBike	submit
# 1	158	361	2024-05-20 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# 2	158	361	2024-05-21 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# 3	158	361	2024-05-22 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# */
#
#
# CREATE TABLE form_170 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`textField` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_170 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	textField	entry_date	last_submit_date
# 1	170	147	29741	114	fakingheaven	2024-06-25 03:24:39	2024-06-25 03:40:37
# 2	170	148	29741	114	yamete	2024-06-25 03:26:41	2024-06-25 03:26:41
# */
#
#
# CREATE TABLE form_171 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`ToWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`FromwhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateForLoanForm` DATETIME,
# 	`eventNameForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm11` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm21` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm12` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm22` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm13` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm23` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm14` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm24` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm15` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm25` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm16` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm26` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm17` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm27` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm18` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm28` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm19` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm29` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm20` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm30` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RequestedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateRequiredWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ApprovedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateItemToBeReturendWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`IssuedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIssueForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReceivedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfReceivedForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReturnedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateRequiredForReturningForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReceivedByWhoForLoanFormForReturning` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfReturnedReceivedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksforLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_171 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	ToWhoForLoanForm	FromwhoForLoanForm	DateForLoanForm	eventNameForLoanForm	QuantityRequiredForLoanForm1	ItemsForLoanForm1	QuantityIssuedForLoanForm1	QuantityReturnedForLoanForm11	RemarksForLoanForm21	QuantityRequiredForLoanForm2	ItemsForLoanForm2	QuantityIssuedForLoanForm2	QuantityReturnedForLoanForm12	RemarksForLoanForm22	QuantityRequiredForLoanForm3	ItemsForLoanForm3	QuantityIssuedForLoanForm3	QuantityReturnedForLoanForm13	RemarksForLoanForm23	QuantityRequiredForLoanForm4	ItemsForLoanForm4	QuantityIssuedForLoanForm4	QuantityReturnedForLoanForm14	RemarksForLoanForm24	QuantityRequiredForLoanForm5	ItemsForLoanForm5	QuantityIssuedForLoanForm5	QuantityReturnedForLoanForm15	RemarksForLoanForm25	QuantityRequiredForLoanForm6	ItemsForLoanForm6	QuantityIssuedForLoanForm6	QuantityReturnedForLoanForm16	RemarksForLoanForm26	QuantityRequiredForLoanForm7	ItemsForLoanForm7	QuantityIssuedForLoanForm7	QuantityReturnedForLoanForm17	RemarksForLoanForm27	QuantityRequiredForLoanForm8	ItemsForLoanForm8	QuantityIssuedForLoanForm8	QuantityReturnedForLoanForm18	RemarksForLoanForm28	QuantityRequiredForLoanForm9	ItemsForLoanForm9	QuantityIssuedForLoanForm9	QuantityReturnedForLoanForm19	RemarksForLoanForm29	QuantityRequiredForLoanForm10	ItemsForLoanForm10	QuantityIssuedForLoanForm10	QuantityReturnedForLoanForm20	RemarksForLoanForm30	RequestedByWhoForLoanForm	DateRequiredWhoForLoanForm	ApprovedByWhoForLoanForm	DateItemToBeReturendWhoForLoanForm	IssuedByWhoForLoanForm	DateOfIssueForLoanForm	ReceivedByWhoForLoanForm	DateOfReceivedForLoanForm	ReturnedByWhoForLoanForm	DateRequiredForReturningForLoanForm	ReceivedByWhoForLoanFormForReturning	DateOfReturnedReceivedByWhoForLoanForm	RemarksforLoanForm	entry_date	last_submit_date
#
# */
# Invoking: `sql_db_query` with `{'query': 'SELECT COUNT(*) as total_meetings FROM form_131'}`
#
#
# [(3,)]There are a total of 3 meetings recorded in the database.
#
# > Finished chain.
# {'input': 'how many meetings are there?',
#  'output': 'There are a total of 3 meetings recorded in the database.'}

# %%
agent_executor.invoke(
    {"input": "how many LEAF meetings are there? Show me the content of one of them"}
)
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# eform_titles, form_127, form_131, form_145, form_155, form_156, form_158, form_170, form_171, form_data_testing
# Invoking: `sql_db_schema` with `{'table_names': 'form_127, form_131, form_145, form_155, form_156, form_158, form_170, form_171'}`
#
#
#
# CREATE TABLE form_127 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_127 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	entry_date	last_submit_date
# 1	127	149	29741	114	2024-06-25 10:19:04	2024-06-25 10:19:04
# 2	127	150	29741	114	2024-06-26 01:57:06	2024-06-26 01:57:06
# 3	127	151	29741	114	2024-06-26 02:02:01	2024-06-26 02:02:01
# */
#
#
# CREATE TABLE form_131 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	`ta_PropertyNameAndDetails` TEXT,
# 	`tf_MeetingMinuteSubject` TEXT,
# 	`dt_DateandTimeOfMeetingMinute` TEXT,
# 	`tf_JointManagementCommitteeMember` TEXT,
# 	`tf_InitialName` TEXT,
# 	`tf_CommitteeUnitNo` TEXT,
# 	`sel_MemberDesignation` TEXT,
# 	`tf_MeetingAttendance` TEXT,
# 	`tf_JointManagementCommitteeMember1` TEXT,
# 	`tf_InitialName1` TEXT,
# 	`tf_CommitteeUnitNo1` TEXT,
# 	`sel_MemberDesignation1` TEXT,
# 	`tf_MeetingAttendance1` TEXT,
# 	`tf_JointManagementCommitteeMember2` TEXT,
# 	`tf_InitialName2` TEXT,
# 	`tf_CommitteeUnitNo2` TEXT,
# 	`sel_MemberDesignation2` TEXT,
# 	`tf_MeetingAttendance2` TEXT,
# 	`tf_JointManagementCommitteeMember3` TEXT,
# 	`tf_InitialName3` TEXT,
# 	`tf_CommitteeUnitNo3` TEXT,
# 	`sel_MemberDesignation3` TEXT,
# 	`tf_MeetingAttendance3` TEXT,
# 	`tf_JointManagementCommitteeMember4` TEXT,
# 	`tf_InitialName4` TEXT,
# 	`tf_CommitteeUnitNo4` TEXT,
# 	`sel_MemberDesignation4` TEXT,
# 	`tf_MeetingAttendance4` TEXT,
# 	`tf_JointManagementCommitteeMember5` TEXT,
# 	`tf_InitialName5` TEXT,
# 	`tf_CommitteeUnitNo5` TEXT,
# 	`sel_MemberDesignation5` TEXT,
# 	`tf_MeetingAttendance5` TEXT,
# 	`Adduserrow2` TEXT,
# 	`Remove3` TEXT,
# 	`NumberOfRows` TEXT,
# 	`tf_PropertyManagementMember` TEXT,
# 	`tf_PropertyManagementMemberInitial` TEXT,
# 	`sel_PropertyManagementMemberDesignation` TEXT,
# 	`tf_PropertyManagementMemberAttendance` TEXT,
# 	`tf_PropertyManagementMember1` TEXT,
# 	`tf_PropertyManagementMemberInitial1` TEXT,
# 	`sel_PropertyManagementMemberDesignation1` TEXT,
# 	`tf_PropertyManagementMemberAttendance1` TEXT,
# 	`tf_PropertyManagementMember2` TEXT,
# 	`tf_PropertyManagementMemberInitial2` TEXT,
# 	`sel_PropertyManagementMemberDesignation2` TEXT,
# 	`tf_PropertyManagementMemberAttendance2` TEXT,
# 	`tf_PropertyManagementMember3` TEXT,
# 	`tf_PropertyManagementMemberInitial3` TEXT,
# 	`sel_PropertyManagementMemberDesignation3` TEXT,
# 	`tf_PropertyManagementMemberAttendance3` TEXT,
# 	`tf_PropertyManagementMember4` TEXT,
# 	`textField41` TEXT,
# 	`sel_PropertyManagementMemberDesignation4` TEXT,
# 	`tf_PropertyManagementMemberAttendance4` TEXT,
# 	`NumberOfPM` TEXT,
# 	`Adduserrow1` TEXT,
# 	`Remove2` TEXT,
# 	`ta_MeetingAnnouncement` TEXT,
# 	`ta_ActionBy` TEXT,
# 	`textArea2` TEXT,
# 	`ta_MeetingAnnouncement1` TEXT,
# 	`ta_ActionBy1` TEXT,
# 	`ta_ActionToBeTaken2` TEXT,
# 	`ta_MeetingAnnouncement3` TEXT,
# 	`ta_ActionBy3` TEXT,
# 	`ta_ActionToBeTaken3` TEXT,
# 	`ta_MeetingAnnouncement4` TEXT,
# 	`ta_ActionBy4` TEXT,
# 	`ta_ActionToBeTaken4` TEXT,
# 	`ta_MeetingAnnouncement5` TEXT,
# 	`ta_ActionBy5` TEXT,
# 	`ta_ActionToBeTaken5` TEXT,
# 	`ta_MeetingAnnouncement6` TEXT,
# 	`ta_ActionBy6` TEXT,
# 	`ta_ActionToBeTaken6` TEXT,
# 	`ta_MeetingAnnouncement7` TEXT,
# 	`ta_ActionBy7` TEXT,
# 	`ta_ActionToBeTaken7` TEXT,
# 	`NumberofAgenda` TEXT,
# 	`Adduserrow3` TEXT,
# 	`Remove4` TEXT,
# 	submit TEXT,
# 	`FormTitle` TEXT,
# 	`FormDescription` TEXT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_131 table:
# id	ta_PropertyNameAndDetails	tf_MeetingMinuteSubject	dt_DateandTimeOfMeetingMinute	tf_JointManagementCommitteeMember	tf_InitialName	tf_CommitteeUnitNo	sel_MemberDesignation	tf_MeetingAttendance	tf_JointManagementCommitteeMember1	tf_InitialName1	tf_CommitteeUnitNo1	sel_MemberDesignation1	tf_MeetingAttendance1	tf_JointManagementCommitteeMember2	tf_InitialName2	tf_CommitteeUnitNo2	sel_MemberDesignation2	tf_MeetingAttendance2	tf_JointManagementCommitteeMember3	tf_InitialName3	tf_CommitteeUnitNo3	sel_MemberDesignation3	tf_MeetingAttendance3	tf_JointManagementCommitteeMember4	tf_InitialName4	tf_CommitteeUnitNo4	sel_MemberDesignation4	tf_MeetingAttendance4	tf_JointManagementCommitteeMember5	tf_InitialName5	tf_CommitteeUnitNo5	sel_MemberDesignation5	tf_MeetingAttendance5	Adduserrow2	Remove3	NumberOfRows	tf_PropertyManagementMember	tf_PropertyManagementMemberInitial	sel_PropertyManagementMemberDesignation	tf_PropertyManagementMemberAttendance	tf_PropertyManagementMember1	tf_PropertyManagementMemberInitial1	sel_PropertyManagementMemberDesignation1	tf_PropertyManagementMemberAttendance1	tf_PropertyManagementMember2	tf_PropertyManagementMemberInitial2	sel_PropertyManagementMemberDesignation2	tf_PropertyManagementMemberAttendance2	tf_PropertyManagementMember3	tf_PropertyManagementMemberInitial3	sel_PropertyManagementMemberDesignation3	tf_PropertyManagementMemberAttendance3	tf_PropertyManagementMember4	textField41	sel_PropertyManagementMemberDesignation4	tf_PropertyManagementMemberAttendance4	NumberOfPM	Adduserrow1	Remove2	ta_MeetingAnnouncement	ta_ActionBy	textArea2	ta_MeetingAnnouncement1	ta_ActionBy1	ta_ActionToBeTaken2	ta_MeetingAnnouncement3	ta_ActionBy3	ta_ActionToBeTaken3	ta_MeetingAnnouncement4	ta_ActionBy4	ta_ActionToBeTaken4	ta_MeetingAnnouncement5	ta_ActionBy5	ta_ActionToBeTaken5	ta_MeetingAnnouncement6	ta_ActionBy6	ta_ActionToBeTaken6	ta_MeetingAnnouncement7	ta_ActionBy7	ta_ActionToBeTaken7	NumberofAgenda	Adduserrow3	Remove4	submit	FormTitle	FormDescription	id_digital_form_io	id_group
# 1	THE TWO CONDO
# Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal Te	LEAF Meeting	2024-05-24T12:00:00+08:00	john	mr	T-04-04	chairman	1/1	Moi	mr	T-05-05	treasurer	1/1	Lisa	ms	T-06-06	secretary	1/1	Lin	mr	T-08-08	treasurer	1/1	Erno	ms	T-11-11	treasurer	1/1	Moon	mr	T-12-12	committee	1/1			0	woos				xander				wukong												0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend	Info		Project Updates:
#
# Project Alpha: Lin reported that the project is on schedule, with the next milesto	Info		Adjournment:
#
# The meeting was adjourned at 11:30 AM.	Info		Asset Management:
#
# Maintenance Activity: swimming pool maintenance needed for June 15, 2024, at 10:0	Info		Next Meeting Date:
#
# The next meeting is scheduled for June 17, 2024, at 10:00 AM in Conference Room 	Info								0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# 2	The Leaf Condominium	MC Meeting No.10	2024-05-17T12:00:00+08:00	Lee Sian Lee	LSL	T-04-04	chairman	1/1	Tan Kim Seng	TKS	T-05-05	secretary	1/1	Wong Wei Kang	WWK	T-06-06	treasurer	1/1	Teow Wei Yoong	TWY	T-08-08	committee	1/1	Lai Choon Fai	LCF	T-11-11	developerRepresentative	1/1	Chong Ken Yung	CKY	T-12-12	developerRepresentative	1/1			0	Chia Wei Ping	CWP	seniorPropertyManager	1/1	Chan Rong Bang	CRB	buildingManager	1/1	Yap Sin Yee	YSY	accountManager	1/1	Thomas Yeap	TY	buildingExecutive	1/1	Jacky Ling	JL	accountExecutive	1/1	0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend	Info		Project Updates:
#
# Project Alpha: CRB reported that the project is on schedule, with the next milesto	Info		Adjournment:
#
# The meeting was adjourned at 11:30 AM.	Info		New Business:
#
# Team Building Activity: CRB suggested organizing a team-building retreat. JL will loo	JL to propose date and venue		Seeking for  Approval to replace faulty swimming pool water pump
#
# CRB reported that the swimming po	PO to be issued by TY		Next Meeting Date:
#
# The next meeting is scheduled for August 17, 2024, at 10:00 AM in Conference Roo	Info					0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# 3	THE TREE CONDO
# Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal T	LEAF Meeting	2024-05-25T12:00:00+08:00	johnny	mr	101	secretary	1/1	joe	mr	102	treasurer	1/1	rang	mrs	103	chairman	1/1																		0																					0			Approval of Previous Minutes:
#
# The minutes from the May 24, 2024 meeting were approved without amend																					0			1	Meeting record for all meeting minutes that related to JMB Management orJMB	Meeting record for all meeting minutes that related to JMB Management orJMB	131	361
# */
#
#
# CREATE TABLE form_145 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`NatureOfIncidentReport` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened` DATETIME,
# 	`LocationOfTheIncidentHappened` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened1` DATETIME,
# 	`LocationOfTheIncidentHappened1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened2` DATETIME,
# 	`LocationOfTheIncidentHappened2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened3` DATETIME,
# 	`LocationOfTheIncidentHappened3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened4` DATETIME,
# 	`LocationOfTheIncidentHappened4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened5` DATETIME,
# 	`LocationOfTheIncidentHappened5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened6` DATETIME,
# 	`LocationOfTheIncidentHappened6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened7` DATETIME,
# 	`LocationOfTheIncidentHappened7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened8` DATETIME,
# 	`LocationOfTheIncidentHappened8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened9` DATETIME,
# 	`LocationOfTheIncidentHappened9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`NatureOfIncidentReport10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIncidentHappened10` DATETIME,
# 	`LocationOfTheIncidentHappened10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ActionTakanDueToTheIncident10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`formTitle` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`formDescription` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_145 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	NatureOfIncidentReport	DateOfIncidentHappened	LocationOfTheIncidentHappened	ActionTakanDueToTheIncident	NatureOfIncidentReport1	DateOfIncidentHappened1	LocationOfTheIncidentHappened1	ActionTakanDueToTheIncident1	NatureOfIncidentReport2	DateOfIncidentHappened2	LocationOfTheIncidentHappened2	ActionTakanDueToTheIncident2	NatureOfIncidentReport3	DateOfIncidentHappened3	LocationOfTheIncidentHappened3	ActionTakanDueToTheIncident3	NatureOfIncidentReport4	DateOfIncidentHappened4	LocationOfTheIncidentHappened4	ActionTakanDueToTheIncident4	NatureOfIncidentReport5	DateOfIncidentHappened5	LocationOfTheIncidentHappened5	ActionTakanDueToTheIncident5	NatureOfIncidentReport6	DateOfIncidentHappened6	LocationOfTheIncidentHappened6	ActionTakanDueToTheIncident6	NatureOfIncidentReport7	DateOfIncidentHappened7	LocationOfTheIncidentHappened7	ActionTakanDueToTheIncident7	NatureOfIncidentReport8	DateOfIncidentHappened8	LocationOfTheIncidentHappened8	ActionTakanDueToTheIncident8	NatureOfIncidentReport9	DateOfIncidentHappened9	LocationOfTheIncidentHappened9	ActionTakanDueToTheIncident9	NatureOfIncidentReport10	DateOfIncidentHappened10	LocationOfTheIncidentHappened10	ActionTakanDueToTheIncident10	formTitle	formDescription	entry_date	last_submit_date
#
# */
#
#
# CREATE TABLE form_155 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL DEFAULT '155',
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	entry_date DATETIME,
# 	status VARCHAR(16) NOT NULL,
# 	by_id_user INTEGER NOT NULL DEFAULT '2',
# 	completed_by_id_user INTEGER NOT NULL DEFAULT '2',
# 	inprogress_by_id_user INTEGER NOT NULL DEFAULT '2',
# 	completed_date DATETIME,
# 	inprogress_date DATETIME,
# 	`PumpOperationCondition` VARCHAR(24),
# 	`FiltrationMediaCondition` VARCHAR(24),
# 	`ElectricalControlPanelOperationCondition` VARCHAR(24),
# 	`ValvesForLeakages` VARCHAR(24),
# 	`RoomCleanliness` VARCHAR(24),
# 	`LooseTerminationOfElectricalCable` VARCHAR(24),
# 	`tf_RemarkFiltrationPumpRoom` VARCHAR(100),
# 	`In-ComingWaterSupplyCondition` VARCHAR(24),
# 	`Ball-ValveOperationCondition` VARCHAR(24),
# 	`Pump-SetOperationCondition` VARCHAR(24),
# 	`tf_RemarkBalancingTank` VARCHAR(100),
# 	`ConditionOfWater` VARCHAR(24),
# 	`WaterOverflowSystemInOrder` VARCHAR(24),
# 	`PresenceAlgaeFormationOnWall` VARCHAR(24),
# 	`CheckTestWaterpH` VARCHAR(24),
# 	`tf_RemarkWadingPool` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_155 table:
# id	id_digital_form_io	id_group	entry_date	status	by_id_user	completed_by_id_user	inprogress_by_id_user	completed_date	inprogress_date	PumpOperationCondition	FiltrationMediaCondition	ElectricalControlPanelOperationCondition	ValvesForLeakages	RoomCleanliness	LooseTerminationOfElectricalCable	tf_RemarkFiltrationPumpRoom	In-ComingWaterSupplyCondition	Ball-ValveOperationCondition	Pump-SetOperationCondition	tf_RemarkBalancingTank	ConditionOfWater	WaterOverflowSystemInOrder	PresenceAlgaeFormationOnWall	CheckTestWaterpH	tf_RemarkWadingPool	submit
# 1	155	361	2024-05-22 16:51:16	completed	29741	2	2	2024-05-25 00:00:00	2024-05-23 00:00:00	ok	ok	ok	not good	not good	ok	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# 2	155	361	2024-05-23 00:00:00	completed	29741	2	2	2024-05-26 00:00:00	2024-05-24 00:00:00	ok	ok	ok	not good	not good	ok	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# 3	155	364	2024-05-24 00:00:00	pending	2	0	0	None	None	not good	ok	ok	not good	not good	not good	Some need new parts	ok	ok	ok	all ok	ok	ok	not good	ok	Need cleaner to clean	1
# */
#
#
# CREATE TABLE form_156 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL DEFAULT '156',
# 	id_group INTEGER NOT NULL DEFAULT '361',
# 	by_id_user INTEGER NOT NULL,
# 	entry_date DATETIME,
# 	`LcdDisplayWestEntrance` VARCHAR(24),
# 	`tf_RemarkLCDDisplayWestEntrance` VARCHAR(100),
# 	`MediaPlayerWestEntrance` VARCHAR(24),
# 	`tf_RemarkMediaPlayerWestEntrance` VARCHAR(100),
# 	`FrontLeftWestEntrance` VARCHAR(24),
# 	`SideWestEntrance` VARCHAR(24),
# 	`RearRightWestEntrance` VARCHAR(24),
# 	`tf_RemarkProjectScreenWestEntrance` VARCHAR(100),
# 	`LeftWestEntrance` VARCHAR(24),
# 	`RightWestEntrance1` VARCHAR(24),
# 	`tf_RemarkVGAPanelWestEntrance` VARCHAR(100),
# 	`LeftWestEntrance1` VARCHAR(24),
# 	`RightWestEntrance` VARCHAR(24),
# 	`tf_RemarkMIGPanelWestEntrance` VARCHAR(100),
# 	`AudioSystemWestEntrance` VARCHAR(24),
# 	`tf_RemarkAudioSystemWestEntrance` VARCHAR(100),
# 	`FOHSpeakerWestEntrance` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerWestEntrance` VARCHAR(100),
# 	`CeilingSpeakerWestEntrance` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerWestEntrance` VARCHAR(100),
# 	`ProtableSystemWestEntrance` VARCHAR(24),
# 	`tf_RemarkPortableSystemWestEntrance` VARCHAR(100),
# 	`StageLightingWestEntrance` VARCHAR(24),
# 	`tf_RemarkStageLightingWestEntrance` VARCHAR(100),
# 	`PowerOutletWestEntrance` VARCHAR(24),
# 	`tf_RemarkPowerOutletWestEntrance` VARCHAR(100),
# 	`LcdDisplayBoardRoom` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBoardRoom` VARCHAR(100),
# 	`MediaPlayerBoardRoom` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBoardRoom` VARCHAR(100),
# 	`FrontLeftBoardRoom` VARCHAR(24),
# 	`SideBoardRoom` VARCHAR(24),
# 	`RearRighBoardRoom` VARCHAR(24),
# 	`tf_RemarkProjectScreenBoardRoom` VARCHAR(100),
# 	`LeftBoardRoom1` VARCHAR(24),
# 	`RightBoardRoom` VARCHAR(24),
# 	`tf_RemarkVGAPanelBoardRoom` VARCHAR(100),
# 	`LeftBoardRoom` VARCHAR(24),
# 	`RightBoardRoom1` VARCHAR(24),
# 	`tf_RemarkMIGPanelBoardRoom` VARCHAR(100),
# 	`AudioSystemBoardRoom` VARCHAR(24),
# 	`tf_RemarkAudioSystemBoardRoom` VARCHAR(100),
# 	`FOHSpeakerBoardRoom` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBoardRoom` VARCHAR(100),
# 	`CeilingSpeakerBoardRoom` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBoardRoom` VARCHAR(100),
# 	`ProtableSystemBoardRoom` VARCHAR(24),
# 	`tf_RemarkPortableSystemBoardRoom` VARCHAR(100),
# 	`StageLightingBoardRoom` VARCHAR(24),
# 	`tf_RemarkStageLightingBoardRoom` VARCHAR(100),
# 	`PowerOutletBoardRoom` VARCHAR(24),
# 	`tf_RemarkPowerOutletBoardRoom` VARCHAR(100),
# 	`LcdDisplayBallRoom1` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom1` VARCHAR(100),
# 	`MediaPlayerBallRoom1` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom1` VARCHAR(100),
# 	`FrontLeftBallRoom1` VARCHAR(24),
# 	`SideBallRoom1` VARCHAR(24),
# 	`RearRightBallRoom1` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom1` VARCHAR(100),
# 	`LeftBallRoom1` VARCHAR(24),
# 	`RightBallRoom1` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom1` VARCHAR(100),
# 	`Left1BallRoom1` VARCHAR(24),
# 	`Right1BallRoom1` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom1` VARCHAR(100),
# 	`AudioSystemBallRoom1` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom1` VARCHAR(100),
# 	`FOHSpeakerBallRoom1` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom1` VARCHAR(100),
# 	`CeilingSpeakerBallRoom1` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom1` VARCHAR(100),
# 	`ProtableSystemBallRoom1` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom1` VARCHAR(100),
# 	`StageLightingBallRoom1` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom1` VARCHAR(100),
# 	`PowerOutletBallRoom1` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom1` VARCHAR(100),
# 	`LcdDisplayBallRoom2` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom2` VARCHAR(100),
# 	`MediaPlayerBallRoom2` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom2` VARCHAR(100),
# 	`FrontLeftBallRoom2` VARCHAR(24),
# 	`SideBallRoom2` VARCHAR(24),
# 	`RearRightBallRoom2` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom2` VARCHAR(100),
# 	`LeftBallRoom2` VARCHAR(24),
# 	`RightBallRoom2` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom2` VARCHAR(100),
# 	`Left1BallRoom2` VARCHAR(24),
# 	`Right1BallRoom2` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom2` VARCHAR(100),
# 	`AudioSystemBallRoom2` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom2` VARCHAR(100),
# 	`FOHSpeakerBallRoom2` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom2` VARCHAR(100),
# 	`CeilingSpeakerBallRoom2` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom2` VARCHAR(100),
# 	`ProtableSystemBallRoom2` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom2` VARCHAR(100),
# 	`StageLightingBallRoom2` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom2` VARCHAR(100),
# 	`PowerOutletBallRoom2` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom2` VARCHAR(100),
# 	`LcdDisplayBallRoom3` VARCHAR(24),
# 	`tf_RemarkLCDDisplayBallRoom3` VARCHAR(100),
# 	`MediaPlayerBallRoom3` VARCHAR(24),
# 	`tf_RemarkMediaPlayerBallRoom3` VARCHAR(100),
# 	`FrontLeftBallRoom3` VARCHAR(24),
# 	`SideBallRoom3` VARCHAR(24),
# 	`RearRightBallRoom3` VARCHAR(24),
# 	`tf_RemarkProjectScreenBallRoom3` VARCHAR(100),
# 	`LeftBallRoom3` VARCHAR(24),
# 	`RightBallRoom3` VARCHAR(24),
# 	`tf_RemarkVGAPanelBallRoom3` VARCHAR(100),
# 	`Left1BallRoom3` VARCHAR(24),
# 	`Right1BallRoom3` VARCHAR(24),
# 	`tf_RemarkMIGPanelBallRoom3` VARCHAR(100),
# 	`AudioSystemBallRoom3` VARCHAR(24),
# 	`tf_RemarkAudioSystemBallRoom3` VARCHAR(100),
# 	`FOHSpeakerBallRoom3` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerBallRoom3` VARCHAR(100),
# 	`CeilingSpeakerBallRoom3` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerBallRoom3` VARCHAR(100),
# 	`ProtableSystemBallRoom3` VARCHAR(24),
# 	`tf_RemarkPortableSystemBallRoom3` VARCHAR(100),
# 	`StageLightingBallRoom3` VARCHAR(24),
# 	`tf_RemarkStageLightingBallRoom3` VARCHAR(100),
# 	`PowerOutletBallRoom3` VARCHAR(24),
# 	`tf_RemarkPowerOutletBallRoom3` VARCHAR(100),
# 	`LcdDisplayEastEntrance` VARCHAR(24),
# 	`tf_RemarkLCDDisplayEastEntrance` VARCHAR(100),
# 	`MediaPlayerEastEntrance` VARCHAR(24),
# 	`tf_RemarkMediaPlayerEastEntrance` VARCHAR(100),
# 	`FrontLeftEastEntrance` VARCHAR(24),
# 	`SideBallEastEntrance` VARCHAR(24),
# 	`RearRightEastEntrance` VARCHAR(24),
# 	`tf_RemarkProjectScreenEastEntrance` VARCHAR(100),
# 	`LeftEastEntrance` VARCHAR(24),
# 	`RightEastEntrance` VARCHAR(24),
# 	`tf_RemarkVGAPanelEastEntrance` VARCHAR(100),
# 	`Left1EastEntrance` VARCHAR(24),
# 	`Right1EastEntrance` VARCHAR(24),
# 	`tf_RemarkMIGPanelEastEntrance` VARCHAR(100),
# 	`AudioSystemEastEntrance` VARCHAR(24),
# 	`tf_RemarkAudioSystemEastEntrance` VARCHAR(100),
# 	`FOHSpeakerEastEntrance` VARCHAR(24),
# 	`tf_RemarkFOHSpeakerEastEntrance` VARCHAR(100),
# 	`CeilingSpeakerEastEntrance` VARCHAR(24),
# 	`tf_RemarkCeilingSpeakerEastEntrance` VARCHAR(100),
# 	`ProtableSystemEastEntrance` VARCHAR(24),
# 	`tf_RemarkPortableSystemEastEntrance` VARCHAR(100),
# 	`StageLightingEastEntrance` VARCHAR(24),
# 	`tf_RemarkStageLightingEastEntrance` VARCHAR(100),
# 	`PowerOutletEastEntrance` VARCHAR(24),
# 	`tf_RemarkPowerOutletEastEntrance` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_156 table:
# id	id_digital_form_io	id_group	by_id_user	entry_date	LcdDisplayWestEntrance	tf_RemarkLCDDisplayWestEntrance	MediaPlayerWestEntrance	tf_RemarkMediaPlayerWestEntrance	FrontLeftWestEntrance	SideWestEntrance	RearRightWestEntrance	tf_RemarkProjectScreenWestEntrance	LeftWestEntrance	RightWestEntrance1	tf_RemarkVGAPanelWestEntrance	LeftWestEntrance1	RightWestEntrance	tf_RemarkMIGPanelWestEntrance	AudioSystemWestEntrance	tf_RemarkAudioSystemWestEntrance	FOHSpeakerWestEntrance	tf_RemarkFOHSpeakerWestEntrance	CeilingSpeakerWestEntrance	tf_RemarkCeilingSpeakerWestEntrance	ProtableSystemWestEntrance	tf_RemarkPortableSystemWestEntrance	StageLightingWestEntrance	tf_RemarkStageLightingWestEntrance	PowerOutletWestEntrance	tf_RemarkPowerOutletWestEntrance	LcdDisplayBoardRoom	tf_RemarkLCDDisplayBoardRoom	MediaPlayerBoardRoom	tf_RemarkMediaPlayerBoardRoom	FrontLeftBoardRoom	SideBoardRoom	RearRighBoardRoom	tf_RemarkProjectScreenBoardRoom	LeftBoardRoom1	RightBoardRoom	tf_RemarkVGAPanelBoardRoom	LeftBoardRoom	RightBoardRoom1	tf_RemarkMIGPanelBoardRoom	AudioSystemBoardRoom	tf_RemarkAudioSystemBoardRoom	FOHSpeakerBoardRoom	tf_RemarkFOHSpeakerBoardRoom	CeilingSpeakerBoardRoom	tf_RemarkCeilingSpeakerBoardRoom	ProtableSystemBoardRoom	tf_RemarkPortableSystemBoardRoom	StageLightingBoardRoom	tf_RemarkStageLightingBoardRoom	PowerOutletBoardRoom	tf_RemarkPowerOutletBoardRoom	LcdDisplayBallRoom1	tf_RemarkLCDDisplayBallRoom1	MediaPlayerBallRoom1	tf_RemarkMediaPlayerBallRoom1	FrontLeftBallRoom1	SideBallRoom1	RearRightBallRoom1	tf_RemarkProjectScreenBallRoom1	LeftBallRoom1	RightBallRoom1	tf_RemarkVGAPanelBallRoom1	Left1BallRoom1	Right1BallRoom1	tf_RemarkMIGPanelBallRoom1	AudioSystemBallRoom1	tf_RemarkAudioSystemBallRoom1	FOHSpeakerBallRoom1	tf_RemarkFOHSpeakerBallRoom1	CeilingSpeakerBallRoom1	tf_RemarkCeilingSpeakerBallRoom1	ProtableSystemBallRoom1	tf_RemarkPortableSystemBallRoom1	StageLightingBallRoom1	tf_RemarkStageLightingBallRoom1	PowerOutletBallRoom1	tf_RemarkPowerOutletBallRoom1	LcdDisplayBallRoom2	tf_RemarkLCDDisplayBallRoom2	MediaPlayerBallRoom2	tf_RemarkMediaPlayerBallRoom2	FrontLeftBallRoom2	SideBallRoom2	RearRightBallRoom2	tf_RemarkProjectScreenBallRoom2	LeftBallRoom2	RightBallRoom2	tf_RemarkVGAPanelBallRoom2	Left1BallRoom2	Right1BallRoom2	tf_RemarkMIGPanelBallRoom2	AudioSystemBallRoom2	tf_RemarkAudioSystemBallRoom2	FOHSpeakerBallRoom2	tf_RemarkFOHSpeakerBallRoom2	CeilingSpeakerBallRoom2	tf_RemarkCeilingSpeakerBallRoom2	ProtableSystemBallRoom2	tf_RemarkPortableSystemBallRoom2	StageLightingBallRoom2	tf_RemarkStageLightingBallRoom2	PowerOutletBallRoom2	tf_RemarkPowerOutletBallRoom2	LcdDisplayBallRoom3	tf_RemarkLCDDisplayBallRoom3	MediaPlayerBallRoom3	tf_RemarkMediaPlayerBallRoom3	FrontLeftBallRoom3	SideBallRoom3	RearRightBallRoom3	tf_RemarkProjectScreenBallRoom3	LeftBallRoom3	RightBallRoom3	tf_RemarkVGAPanelBallRoom3	Left1BallRoom3	Right1BallRoom3	tf_RemarkMIGPanelBallRoom3	AudioSystemBallRoom3	tf_RemarkAudioSystemBallRoom3	FOHSpeakerBallRoom3	tf_RemarkFOHSpeakerBallRoom3	CeilingSpeakerBallRoom3	tf_RemarkCeilingSpeakerBallRoom3	ProtableSystemBallRoom3	tf_RemarkPortableSystemBallRoom3	StageLightingBallRoom3	tf_RemarkStageLightingBallRoom3	PowerOutletBallRoom3	tf_RemarkPowerOutletBallRoom3	LcdDisplayEastEntrance	tf_RemarkLCDDisplayEastEntrance	MediaPlayerEastEntrance	tf_RemarkMediaPlayerEastEntrance	FrontLeftEastEntrance	SideBallEastEntrance	RearRightEastEntrance	tf_RemarkProjectScreenEastEntrance	LeftEastEntrance	RightEastEntrance	tf_RemarkVGAPanelEastEntrance	Left1EastEntrance	Right1EastEntrance	tf_RemarkMIGPanelEastEntrance	AudioSystemEastEntrance	tf_RemarkAudioSystemEastEntrance	FOHSpeakerEastEntrance	tf_RemarkFOHSpeakerEastEntrance	CeilingSpeakerEastEntrance	tf_RemarkCeilingSpeakerEastEntrance	ProtableSystemEastEntrance	tf_RemarkPortableSystemEastEntrance	StageLightingEastEntrance	tf_RemarkStageLightingEastEntrance	PowerOutletEastEntrance	tf_RemarkPowerOutletEastEntrance	submit
# 1	156	361	29741	2024-05-05 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		1
# 2	156	361	29741	2024-05-12 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok											None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# 3	156	361	29741	2024-05-19 17:07:56	ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok												ok		ok		ok		ok		ok		ok		ok		ok										None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE form_158 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL COMMENT 'FK to eform_titles.id_digital_form_io' DEFAULT '158',
# 	id_group INTEGER NOT NULL COMMENT 'FK to groups' DEFAULT '361',
# 	entry_date DATETIME COMMENT 'Date of submission',
# 	`DBBoardSwitches` VARCHAR(24),
# 	`Treadmill1` VARCHAR(24),
# 	`Treadmill3` VARCHAR(24),
# 	`CrossTrainer1` VARCHAR(24),
# 	`UprightBike` VARCHAR(24),
# 	`ERower` VARCHAR(24),
# 	`LegExtension` VARCHAR(24),
# 	`LatPullDown` VARCHAR(24),
# 	`AdjustableBench` VARCHAR(24),
# 	`2TierRack` VARCHAR(24),
# 	`Upholstery` VARCHAR(24),
# 	`SwingDoor` VARCHAR(24),
# 	`Mirror` VARCHAR(24),
# 	`WallSwitchSocket` VARCHAR(24),
# 	`WallFan` VARCHAR(24),
# 	`TimberFlooring` VARCHAR(24),
# 	`Treadmill2` VARCHAR(24),
# 	`Treadmill4` VARCHAR(24),
# 	`CrossTrainer12` VARCHAR(24),
# 	`RecumbentBike` VARCHAR(24),
# 	`MultiPress` VARCHAR(24),
# 	`Abdominal` VARCHAR(24),
# 	`AbdominalBench` VARCHAR(24),
# 	`AdjustableBench2` VARCHAR(24),
# 	`PullPins` VARCHAR(24),
# 	cables VARCHAR(24),
# 	`Emergency` VARCHAR(24),
# 	`CeilingLights` VARCHAR(24),
# 	`Aircond` VARCHAR(24),
# 	`tf_RemarkRecumbentBike` VARCHAR(100),
# 	submit VARCHAR(100),
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_0900_ai_ci
#
# /*
# 3 rows from form_158 table:
# id	id_digital_form_io	id_group	entry_date	DBBoardSwitches	Treadmill1	Treadmill3	CrossTrainer1	UprightBike	ERower	LegExtension	LatPullDown	AdjustableBench	2TierRack	Upholstery	SwingDoor	Mirror	WallSwitchSocket	WallFan	TimberFlooring	Treadmill2	Treadmill4	CrossTrainer12	RecumbentBike	MultiPress	Abdominal	AbdominalBench	AdjustableBench2	PullPins	cables	Emergency	CeilingLights	Aircond	tf_RemarkRecumbentBike	submit
# 1	158	361	2024-05-20 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# 2	158	361	2024-05-21 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# 3	158	361	2024-05-22 00:00:00	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	not okay	okay	okay	okay	okay	Need to check again	1
# */
#
#
# CREATE TABLE form_170 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`textField` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_170 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	textField	entry_date	last_submit_date
# 1	170	147	29741	114	fakingheaven	2024-06-25 03:24:39	2024-06-25 03:40:37
# 2	170	148	29741	114	yamete	2024-06-25 03:26:41	2024-06-25 03:26:41
# */
#
#
# CREATE TABLE form_171 (
# 	id INTEGER UNSIGNED NOT NULL AUTO_INCREMENT,
# 	id_digital_form_io INTEGER NOT NULL,
# 	id_digital_form_io_submission INTEGER NOT NULL,
# 	id_user INTEGER NOT NULL,
# 	id_group INTEGER NOT NULL,
# 	`ToWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`FromwhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateForLoanForm` DATETIME,
# 	`eventNameForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm1` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm11` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm21` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm2` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm12` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm22` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm3` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm13` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm23` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm4` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm14` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm24` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm5` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm15` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm25` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm6` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm16` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm26` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm7` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm17` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm27` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm8` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm18` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm28` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm9` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm19` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm29` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityRequiredForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ItemsForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityIssuedForLoanForm10` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`QuantityReturnedForLoanForm20` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksForLoanForm30` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RequestedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateRequiredWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ApprovedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateItemToBeReturendWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`IssuedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfIssueForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReceivedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfReceivedForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReturnedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateRequiredForReturningForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`ReceivedByWhoForLoanFormForReturning` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`DateOfReturnedReceivedByWhoForLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	`RemarksforLoanForm` VARCHAR(150) COLLATE utf8mb4_unicode_ci,
# 	entry_date DATETIME NOT NULL,
# 	last_submit_date DATETIME NOT NULL,
# 	PRIMARY KEY (id)
# )DEFAULT CHARSET=utf8mb4 ENGINE=InnoDB COLLATE utf8mb4_unicode_ci
#
# /*
# 3 rows from form_171 table:
# id	id_digital_form_io	id_digital_form_io_submission	id_user	id_group	ToWhoForLoanForm	FromwhoForLoanForm	DateForLoanForm	eventNameForLoanForm	QuantityRequiredForLoanForm1	ItemsForLoanForm1	QuantityIssuedForLoanForm1	QuantityReturnedForLoanForm11	RemarksForLoanForm21	QuantityRequiredForLoanForm2	ItemsForLoanForm2	QuantityIssuedForLoanForm2	QuantityReturnedForLoanForm12	RemarksForLoanForm22	QuantityRequiredForLoanForm3	ItemsForLoanForm3	QuantityIssuedForLoanForm3	QuantityReturnedForLoanForm13	RemarksForLoanForm23	QuantityRequiredForLoanForm4	ItemsForLoanForm4	QuantityIssuedForLoanForm4	QuantityReturnedForLoanForm14	RemarksForLoanForm24	QuantityRequiredForLoanForm5	ItemsForLoanForm5	QuantityIssuedForLoanForm5	QuantityReturnedForLoanForm15	RemarksForLoanForm25	QuantityRequiredForLoanForm6	ItemsForLoanForm6	QuantityIssuedForLoanForm6	QuantityReturnedForLoanForm16	RemarksForLoanForm26	QuantityRequiredForLoanForm7	ItemsForLoanForm7	QuantityIssuedForLoanForm7	QuantityReturnedForLoanForm17	RemarksForLoanForm27	QuantityRequiredForLoanForm8	ItemsForLoanForm8	QuantityIssuedForLoanForm8	QuantityReturnedForLoanForm18	RemarksForLoanForm28	QuantityRequiredForLoanForm9	ItemsForLoanForm9	QuantityIssuedForLoanForm9	QuantityReturnedForLoanForm19	RemarksForLoanForm29	QuantityRequiredForLoanForm10	ItemsForLoanForm10	QuantityIssuedForLoanForm10	QuantityReturnedForLoanForm20	RemarksForLoanForm30	RequestedByWhoForLoanForm	DateRequiredWhoForLoanForm	ApprovedByWhoForLoanForm	DateItemToBeReturendWhoForLoanForm	IssuedByWhoForLoanForm	DateOfIssueForLoanForm	ReceivedByWhoForLoanForm	DateOfReceivedForLoanForm	ReturnedByWhoForLoanForm	DateRequiredForReturningForLoanForm	ReceivedByWhoForLoanFormForReturning	DateOfReturnedReceivedByWhoForLoanForm	RemarksforLoanForm	entry_date	last_submit_date
#
# */
# Invoking: `sql_db_query` with `{'query': 'SELECT COUNT(*) AS total_meetings FROM form_131'}`
#
#
# [(3,)]
# Invoking: `sql_db_query` with `{'query': 'SELECT * FROM form_131 LIMIT 1'}`
#
#
# [(1, 'THE TWO CONDO\nTingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal Territory of Kuala Lumpur', 'LEAF Meeting', '2024-05-24T12:00:00+08:00', 'john', 'mr', 'T-04-04', 'chairman', '1/1', 'Moi', 'mr', 'T-05-05', 'treasurer', '1/1', 'Lisa', 'ms', 'T-06-06', 'secretary', '1/1', 'Lin', 'mr', 'T-08-08', 'treasurer', '1/1', 'Erno', 'ms', 'T-11-11', 'treasurer', '1/1', 'Moon', 'mr', 'T-12-12', 'committee', '1/1', '', '', '0', 'woos', '', '', '', 'xander', '', '', '', 'wukong', '', '', '', '', '', '', '', '', '', '', '', '0', '', '', 'Approval of Previous Minutes:\n\nThe minutes from the May 24, 2024 meeting were approved without amendments.', 'Info', '', 'Project Updates:\n\nProject Alpha: Lin reported that the project is on schedule, with the next milestone expected to be completed by June 1.\nProject Beta: Yeap mentioned some delays due to supply chain issues, but a new supplier has been secured.', 'Info', '', 'Adjournment:\n\nThe meeting was adjourned at 11:30 AM.', 'Info', '', 'Asset Management:\n\nMaintenance Activity: swimming pool maintenance needed for June 15, 2024, at 10:00 AM', 'Info', '', 'Next Meeting Date:\n\nThe next meeting is scheduled for June 17, 2024, at 10:00 AM in Conference Room A.', 'Info', '', '', '', '', '', '', '', '0', '', '', '1', 'Meeting record for all meeting minutes that related to JMB Management orJMB', 'Meeting record for all meeting minutes that related to JMB Management orJMB', 131, 361)]There are a total of 3 LEAF meetings recorded in the database.
#
# Here is the content of one of the LEAF meetings:
#
# - **Property Details**: THE TWO CONDO, Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal Territory of Kuala Lumpur
# - **Meeting Subject**: LEAF Meeting
# - **Date and Time of Meeting**: May 24, 2024, at 12:00 PM
# - **Attendees and Roles**:
#   - John (Mr.), T-04-04, Chairman, Attendance: 1/1
#   - Moi (Mr.), T-05-05, Treasurer, Attendance: 1/1
#   - Lisa (Ms.), T-06-06, Secretary, Attendance: 1/1
#   - Lin (Mr.), T-08-08, Treasurer, Attendance: 1/1
#   - Erno (Ms.), T-11-11, Treasurer, Attendance: 1/1
#   - Moon (Mr.), T-12-12, Committee, Attendance: 1/1
#
# - **Meeting Proceedings**:
#   - **Approval of Previous Minutes**: The minutes from the May 24, 2024 meeting were approved without amendments.
#   - **Project Updates**: Project Alpha: Lin reported that the project is on schedule, with the next milestone expected to be completed by June 1. Project Beta: Yeap mentioned some delays due to supply chain issues, but a new supplier has been secured.
#   - **Adjournment**: The meeting was adjourned at 11:30 AM.
#   - **Asset Management**: Maintenance Activity: swimming pool maintenance needed for June 15, 2024, at 10:00 AM.
#   - **Next Meeting Date**: The next meeting is scheduled for June 17, 2024, at 10:00 AM in Conference Room A.
#
# > Finished chain.
# {'input': 'how many LEAF meetings are there? Show me the content of one of them',
#  'output': 'There are a total of 3 LEAF meetings recorded in the database.\n\nHere is the content of one of the LEAF meetings:\n\n- **Property Details**: THE TWO CONDO, Tingkat 18, Menara TH Perdana, 1001, Jln Sultan Ismail, 50250 Kuala Lumpur, Federal Territory of Kuala Lumpur\n- **Meeting Subject**: LEAF Meeting\n- **Date and Time of Meeting**: May 24, 2024, at 12:00 PM\n- **Attendees and Roles**:\n  - John (Mr.), T-04-04, Chairman, Attendance: 1/1\n  - Moi (Mr.), T-05-05, Treasurer, Attendance: 1/1\n  - Lisa (Ms.), T-06-06, Secretary, Attendance: 1/1\n  - Lin (Mr.), T-08-08, Treasurer, Attendance: 1/1\n  - Erno (Ms.), T-11-11, Treasurer, Attendance: 1/1\n  - Moon (Mr.), T-12-12, Committee, Attendance: 1/1\n\n- **Meeting Proceedings**:\n  - **Approval of Previous Minutes**: The minutes from the May 24, 2024 meeting were approved without amendments.\n  - **Project Updates**: Project Alpha: Lin reported that the project is on schedule, with the next milestone expected to be completed by June 1. Project Beta: Yeap mentioned some delays due to supply chain issues, but a new supplier has been secured.\n  - **Adjournment**: The meeting was adjourned at 11:30 AM.\n  - **Asset Management**: Maintenance Activity: swimming pool maintenance needed for June 15, 2024, at 10:00 AM.\n  - **Next Meeting Date**: The next meeting is scheduled for June 17, 2024, at 10:00 AM in Conference Room A.'}
